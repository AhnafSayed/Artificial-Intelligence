# %% [markdown]
# #  Ahnaf Sayed, ID: 18-36920-1, Section-F, Week 8

# %% [markdown]
# # Problem: Maximie f(x) = x^2 when x= 1 to 31

# %% [markdown]
# # Step 1: Initialize Population

# %%
[i for i in range(4)]
# Out:
# [0, 1, 2, 3]

# %%
import random
def initPopulation(n,b):
    p={}
    for i in range(n):
        s=[]
        for j in range(b):
            s.append(random.choice([0,1]))    
        p[i]=s
    return p

# %%
population=initPopulation(6,5)
population
# Out:
# {0: [1, 1, 1, 1, 0],
#  1: [0, 0, 1, 1, 0],
#  2: [1, 1, 1, 0, 0],
#  3: [0, 1, 0, 1, 0],
#  4: [1, 1, 1, 0, 1],
#  5: [0, 0, 1, 1, 0]}

# %% [markdown]
# # Step 2: Parent Selection

# %% [markdown]
# Fitness Calculation

# %%
[i for i in range(4,-1,-1)]
# Out:
# [4, 3, 2, 1, 0]

# %%
def getFitness(p):
    f=[]
    for k in p.keys():
        d = 0
        b = len(p[k])
        for i in range(b-1,-1,-1):
            d=d+p[k][i]*2**(4-i)
        f.append(d**2)
    return f

# %%
fitness = getFitness(population)
fitness
# Out:
# [900, 36, 784, 100, 841, 36]

# %% [markdown]
# calculate probability and select parents

# %%
def select_parent(n,fitness):
    total_fitness = sum(fitness)
    probabilities = [round(f/total_fitness,3) for f in fitness]
    parents = {}
    for i in range(n):
        r =random.choice(range(1,1001,1))/1000
        s = 0
        for j in range(len(probabilities)):
            s = s + probabilities[j]
            if(s>r):
                parents[i]=population[j]
                #print(population[j])
                break
    return parents

# %%
parents = select_parent(4,fitness)
parents
# Out:
# {0: [1, 1, 1, 0, 0],
#  1: [1, 1, 1, 0, 1],
#  2: [1, 1, 1, 1, 0],
#  3: [1, 1, 1, 0, 0]}

# %% [markdown]
# # Step 3: Crossover

# %%
cp = random.choice(range(1,5))
cp
# Out:
# 1

# %%
def Crossover(self, guardians):
    Father, Mother = guardians
    dic1 = random.randint(1, len(self.target) - 2)
    dic2 = random.randint(1, len(self.target) - 2)
    if dic1 > dic2: 
        dic1, dic2 = dic2, dic1
        Child1 = Father[:dic1] + Mother[dic1:index2] + Father[dic2:]
        Child2 = Mother[:dic1] + Father[dic1:dic2] + Mother[dic2:]
        
        
    return (Child1, Child2)

# %%
def Mutation(self, chromosome):
    index = random.randint(0, len(self.target) - 1)
    vary = random.randint(-5, 5)
    mutated = list(chromosome)
    mutated[index] += vary
    
    
    return mutated
