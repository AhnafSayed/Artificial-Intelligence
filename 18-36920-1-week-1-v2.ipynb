# %% [markdown]
# #  Ahnaf Sayed, ID: 18-36920-1, Section-F, Week 1

# %% [markdown]
# # Number expression:

# %%
a=100
b=150
c=100
a+b+c
# Out:
# 350

# %%
(a+b+c)*4
# Out:
# 1400

# %%
(a+b+c)**6
# Out:
# 1838265625000000

# %%
print(a+b+c)
# Out:
# 350

# %%
a==c
# Out:
# True

# %%
a==b
# Out:
# False

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
import random
random.random()
# Out:
# 0.3210904667771438

# %%
random.choice([6,7,8,9])
# Out:
# 6

# %% [markdown]
# # String examples:

# %%
s= 'Bay of Bengal'
s
# Out:
# 'Bay of Bengal'

# %%
s[7]
# Out:
# 'B'

# %%
s[:]
# Out:
# 'Bay of Bengal'

# %%
s[7:]
# Out:
# 'Bengal'

# %%
s[-1]
# Out:
# 'l'

# %%
len(s)
# Out:
# 13

# %%
s[:3]
# Out:
# 'Bay'

# %%
s[:6]
# Out:
# 'Bay of'

# %%
s[:-2]
# Out:
# 'Bay of Beng'

# %%
s+' is situated at the south of Bangladesh'
# Out:
# 'Bay of Bengal is situated at the south of Bangladesh'

# %%
s*9
# Out:
# 'Bay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of Bengal'

# %%
s.find('Bengal')
# Out:
# 7

# %%
s.replace('Bengal','Bangladesh')
# Out:
# 'Bay of Bangladesh'

# %%
s='Bangladesh'+s[6:]
s
# Out:
# 'Bangladesh Bengal'

# %%
s.upper()
# Out:
# 'BANGLADESH BENGAL'

# %%
print(s.upper())
# Out:
# BANGLADESH BENGAL

# %%
print(s.lower())
# Out:
# bangladesh bengal

# %%
address='Uttara Dhaka 1230'
address.split(' ')
# Out:
# ['Uttara', 'Dhaka', '1230']

# %%
s.isalpha()
# Out:
# False

# %%
address=address.rstrip()
address
# Out:
# 'Uttara Dhaka 1230'

# %%
name='Bay of Bengal'
firstN=name.split(' ')[0]
lastN=name.split(' ')[-1]
print(firstN)
print(lastN)
# Out:
# Bay
# Bengal

# %% [markdown]
# # List examples:

# %%
D=[123,'Hello',3.1416,'World']
len(Digit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-3068da529696> in <module>
#       1 D=[123,'Hello',3.1416,'World']
# ----> 2 len(Digit)
#
# NameError: name 'Digit' is not defined

# %%
D+[7,8,9,10]

# %%
D[:-1]

# %%
D.append('Universe')
D

# %%
D.pop(4)

# %% [markdown]
# Continue

# %%
D

# %%
A=['E','F','G','A','C','B','D']
A.sort()
A

# %%
A.reverse()
A

# %%
A=[[7,8,9,5],
  [2,3,4,7],
  [6,5,2,1],
  [7,1,4,3]]
A

# %%
col3=[row[3]for row in A]
col3

# %%
[row[3]+4 for row in A]

# %%
[col[3]+7 for col in A]

# %%
[row[2] for row in A if row[2] % 2 == 0]

# %%
[col[1]for col in A if col[1] % 2 == 0]

# %%
A[2]

# %%
A[0][3]

# %%
diag=[A[j][j]for j in [0,1,2,3]]
diag

# %%
doubles=[l*8 for l in 'hello universe']
doubles

# %% [markdown]
# # Dictionaries examples:

# %%
H={'Car Name': 'Audi','Model': 'RS4', 'Class': 'Sports Car', 'Max Horsepower': 444}
H
# Out:
# {'Car Name': 'Audi',
#  'Model': 'RS4',
#  'Class': 'Sports Car',
#  'Max Horsepower': 444}

# %%
H['Car Name']

# %%
H['Class']

# %%
H['Max Horsepower']+=27
H

# %%
H['Max Horsepower']/=222
H

# %%
C = {}
C['Vehicle Brand'] = 'Audi' 
C['Model'] = 'R8'
C['CC'] = 5934
C['Class']= 'Sports Car'
C

# %%
print (C['Class'])

# %%
print (C['Model'])

# %%
Z={'Vehicle Name': {'First Name': 'Audi', 'Last Name': 'R8'},
'Class': ['Super Car', 'Executive Car'],
'CC': 5934,
'Max Horsepower': 562}
Z

# %%
Z['Max Horsepower']

# %%
Z['Vehicle Name']['First Name']

# %%
Z['Class'][-1]

# %%
Z['Class'].append('Sedan')
Z

# %%
X={'W': 6, 'X': 7, 'Y': 8, 'Z': 9}
X

# %%
Q=X.keys()
Q

# %%
for key in Q:
    print (key, '=>', X[key])

# %%
for key in sorted(X):
    print (key, '=>', X[key])

# %%
for x in 'Hello World':
    print (x.upper())

# %%
Power=[a ** 4 for a in [4, 5, 6, 7, 8, 9]]
Power

# %%
Power=[]
for a in [4, 5, 6, 7, 8, 9]: 
    Power.append(a ** 4)
Power

# %%
H['CC']=5934
H
# Out:
# {'Car Name': 'Audi',
#  'Model': 'RS4',
#  'Class': 'Sports Car',
#  'Max Horsepower': 444,
#  'CC': 5934}

# %%
('z') in H
# Out:
# False

# %%
if not ('z') in H:
    print ("None")
# Out:
# None

# %%
if ('CC') in H:
    print("Available in the dictionary")
# Out:
# Available in the dictionary

# %%
M=(5,6,7,8,10,12,13,14,15,19)
len(M)
# Out:
# 10

# %%
M+(16,17,18,20)
# Out:
# (5, 6, 7, 8, 10, 12, 13, 14, 15, 19, 16, 17, 18, 20)

# %%
M[6]
# Out:
# 13

# %%
v= open('Saved data.txt', 'w')
v.write('Bay\n') 
v.write('of\n')
v.write('Bengal\n')
v.close( )
v
# Out:
# <_io.TextIOWrapper name='Saved data.txt' mode='w' encoding='UTF-8'>

# %%
v=open('Saved data.txt') 
bytes = v.read( ) 
bytes
# Out:
# 'Bay\nof\nBengal\n'

# %%
print (bytes)
# Out:
# Bay
# of
# Bengal

# %%
bytes.split()
# Out:
# ['Bay', 'of', 'Bengal']

# %%
A=set('Hello World')
B= set(['Hello', 'Universe'])
A,B
# Out:
# ({' ', 'H', 'W', 'd', 'e', 'l', 'o', 'r'}, {'Hello', 'Universe'})

# %%
A & B
# Out:
# set()

# %%
A|B
# Out:
# {' ', 'H', 'Hello', 'Universe', 'W', 'd', 'e', 'l', 'o', 'r'}

# %%
A-B
# Out:
# {' ', 'H', 'W', 'd', 'e', 'l', 'o', 'r'}

# %%
import decimal
c=decimal.Decimal('6.4167')
c+6
# Out:
# Decimal('12.4167')

# %%
6>7, 8<9
# Out:
# (False, True)

# %%
A=(['Hello World']* 70)
A
# Out:
# ['Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
#  'Hello World',
# ...
