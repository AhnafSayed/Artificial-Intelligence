# %% [markdown]
# #  Ahnaf Sayed, ID: 18-36920-1, Section-F, Week 2

# %% [markdown]
# # Lesson: 3

# %%
len([7,8,9,10,13])

# %%
[7,8,9,10,13]+[1,2,3,4,5,6]

# %%
['Hello Universe']*11

# %%
7 in [7,8,9,10]

# %%
23 in [13,14,15,16]

# %%
for a in [3,4,6,8,9,13,14]: 
    print (a)

# %%
str([14,16,18,20])+"22,24"

# %%
[3,4,5,6]+ list("789")

# %%
A1=['Hello','Whole','Universe','Galaxy']
A2=['Bay','of','Bengal']
A3=['Porsche','Carrera','GT']
A1[3]

# %%
A3[2]

# %%
A2[1:-1]

# %%
A1[-1]

# %%
A1[2:-1]

# %%
hexa=[[11,13,15,17,19,21],[12,14,16,18,20,22],[23,25,27,29,31,33],[24,26,28,30,32,34]]
hexa[3]

# %%
hexa[3][5]

# %%
hexa[1][4]

# %%
hexa[2][4]

# %%
hexa[0][0]=12
hexa[3][3]=32
hexa

# %%
A = ['Hello', 'Universe', 'Galaxy','Black']
A[1] = 'Whole'
A

# %%
A[1:] = ['From', 'Planet','Earth']
A

# %%
A.append('People') 
A

# %%
A.sort()
A

# %%
A=[22,23,24,26,27]
A.extend([21,28,29,30])
A.sort()
A

# %%
A.pop()

# %%
A.reverse()
A

# %%
A=[]
A.append(11)
A.append(12)
A.append(13)
A.append(14)
A.append(15)
A

# %%
A.pop()
A

# %%
A = ['Hello', 'Universe', 'Galaxy','Black']
del A[3]
A

# %%
del A[1:-1]
A

# %%
A=['Hello','World','Universe']
A[:1]=['Bye']
A

# %%
A[0]=['Hello']
A

# %%
Car={'Name':'Porsche','Type':'Sports Car','Horsepower':783,'CC':6482}
Car['Type']

# %%
len(Car)

# %%
'Horsepower' in Car

# %%
Car.keys()

# %%
Car['Type']='Hyper Car','Sedan','Hatchback'
Car

# %%
del Car['CC']
Car['Version']='Carrera GT'
Car

# %%
Car.get('Name')

# %%
Car.get('Speed')

# %%
Car.get('Speed',345)

# %%
Car2={'Transmission':'6 Speed Manual','Assembly':'Germany','Production': 2003}
Car2

# %%
Car2={'Transmission':'6 Speed Manual','Assembly':'Germany','Production': 2003}
Car.update(Car2)
Car

# %%
Car.pop('Assembly')
Car.pop('Production')
Car

# %%
Words=['Hello','Universe','Planet','Galaxy','Microwave']
Words.pop()
Words.pop(3)
Words

# %%
Car={'Vehicle Name': 'Porsche Carrera GT',
    'Type': 'Sports Car',
    'Horsepower': 578,
    'Production': 'Germany'}

Chesis='Vehicle Name'
Body= Car[Chesis]
Body

# %%
for Chesis1 in Car.keys():
    print (Chesis1,'\t',Car[Chesis1])

# %%
Quad={}
Quad[(7,8,9,10,12)]=777
Quad[(14,15,16,17,18)]=442
Quad[(22,23,24,25,26)]=899
Quad[(31,32,33,34,35)]=396

A=22;B=23;C=24;D=25;E=26
Quad[(A,B,C,D,E)]

# %%
Quad

# %%
if ((14,15,16,17,18)) in Quad:
    print (Quad[(14,15,16,17,18)])
else:
    print ('Not Available')

# %%
try:
    print (Quad[(31,32,33,34,35)])
except KeyError:
        print (100)

# %%
Quad.get((31,32,33,34,35), 'No match')

# %%
Quad.get((31,32,33,37,35), 'No match!')

# %%
Save={}
Save['Vehicle Brand']='Porsche'
Save['Horsepower']=684
Save['Origin']='Germany'
Save['CC']=5578

print (Save['Origin'])

# %%
Porsche={'Full Name': 'Porsche Carrera GT',
'Horsepower': {'Minimum':578,'Medium':588,'Maximum':600},
'Origin': {'Germany'},
'Production': {'Area': 'Leipzig', 'Number':1876},
'CC':{5778}}

# %%
Porsche['Production']['Number']

# %%
Porsche['Horsepower']['Maximum']

# %% [markdown]
# # Lesson: 5

# %%
while True:    
    Text=input('Enter any text:')
    if Text=='Stop':break
    print (Text.upper( ))
print('Stopped')
# Out:
# Enter any text:Stop
# Stopped

# %%
while True:    
    Number=input('Enter any number for N²: ')
    if Number=='Stop':break
    print (int(Number)**2)
print('See you later!')
# Out:
# Enter any number for N²: Stop
# See you later!

# %%
while True:
    Number=input('Enter any number for N²: ')
    if Text=='Stop':
        break
    elif not Number.isdigit( ):
        print ('Only numbers allowed!'*1)
    else:
        print (int(Number)**2)
    print ('See you later!')
# Out:
# Enter any number for N²: Stop
# Only numbers allowed!
# See you later!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/conda/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     806         try:
# --> 807             msg_list = socket.recv_multipart(mode, copy=copy)
#     808         except zmq.ZMQError as e:
#
# /opt/conda/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %% [markdown]
# # Try Example:

# %%
while True:
    Number=input('Enter any number for N²: ')
    if Text=='Stop':
        break
    try:
        num=int(Number)
    except:
        print ('Only numbers allowed!'*1)
    else:
        print (int(Number)**2)
    print ('See you later!')
# Out:
# Enter any number for N²: Stop
# Only numbers allowed!
# See you later!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/conda/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     806         try:
# --> 807             msg_list = socket.recv_multipart(mode, copy=copy)
#     808         except zmq.ZMQError as e:
#
# /opt/conda/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
while True:
    Set=input('Enter any number for N²: ')
    if Set=='Stop':
        break
    elif not Set.isdigit( ):
        print ('Only numbers allowed!'*1)
    else:
        Number=int(Set)
    if Number>50:
        print ('High')
    else:
        print (Number**2)
print ('See you later!')
# Out:
# Enter any number for N²: 51
# High
# Enter any number for N²: 20
# 400
# Enter any number for N²: 2
# 4
# Enter any number for N²: 60
# High
# Enter any number for N²: Stop
# See you later!

# %% [markdown]
# # Method:

# %%
def get_names(name):
    M=Name.split()
    FirstName=M[0]
    LastName=M[-1]
get_names(
Mid=' '
  if len(M)>2:
Mid=M[1]
  for v in M[2:-1]:
    Mid=Mid+' '+v
return FirstName,Mid,LastName)
# Out:
#   File "<ipython-input-130-0a830503f58e>", line 7
#     if len(M)>2:
#                ^
# SyntaxError: invalid syntax
