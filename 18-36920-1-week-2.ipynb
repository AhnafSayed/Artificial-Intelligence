# %% [markdown]
# #  Ahnaf Sayed, ID: 18-36920-1, Section-F, Week 2

# %% [markdown]
# # Lesson: 3

# %%
len([7,8,9,10,13])
# Out:
# 5

# %%
[7,8,9,10,13]+[1,2,3,4,5,6]
# Out:
# [7, 8, 9, 10, 13, 1, 2, 3, 4, 5, 6]

# %%
['Hello Universe']*11
# Out:
# ['Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe',
#  'Hello Universe']

# %%
7 in [7,8,9,10]
# Out:
# True

# %%
23 in [13,14,15,16]
# Out:
# False

# %%
for a in [3,4,6,8,9,13,14]: 
    print (a)
# Out:
# 3
# 4
# 6
# 8
# 9
# 13
# 14

# %%
str([14,16,18,20])+"22,24"
# Out:
# '[14, 16, 18, 20]22,24'

# %%
[3,4,5,6]+ list("789")
# Out:
# [3, 4, 5, 6, '7', '8', '9']

# %%
A1=['Hello','Whole','Universe','Galaxy']
A2=['Bay','of','Bengal']
A3=['Porsche','Carrera','GT']
A1[3]
# Out:
# 'Galaxy'

# %%
A3[2]
# Out:
# 'GT'

# %%
A2[1:-1]
# Out:
# ['of']

# %%
A1[-1]
# Out:
# 'Galaxy'

# %%
A1[2:-1]
# Out:
# ['Universe']

# %%
hexa=[[11,13,15,17,19,21],[12,14,16,18,20,22],[23,25,27,29,31,33],[24,26,28,30,32,34]]
hexa[3]
# Out:
# [24, 26, 28, 30, 32, 34]

# %%
hexa[3][5]
# Out:
# 34

# %%
hexa[1][4]
# Out:
# 20

# %%
hexa[2][4]
# Out:
# 31

# %%
hexa[0][0]=12
hexa[3][3]=32
hexa
# Out:
# [[12, 13, 15, 17, 19, 21],
#  [12, 14, 16, 18, 20, 22],
#  [23, 25, 27, 29, 31, 33],
#  [24, 26, 28, 32, 32, 34]]

# %%
A = ['Hello', 'Universe', 'Galaxy','Black']
A[1] = 'Whole'
A
# Out:
# ['Hello', 'Whole', 'Galaxy', 'Black']

# %%
A[1:] = ['From', 'Planet','Earth']
A
# Out:
# ['Hello', 'From', 'Planet', 'Earth']

# %%
A.append('People') 
A
# Out:
# ['Hello', 'From', 'Planet', 'Earth', 'People']

# %%
A.sort()
A
# Out:
# ['Earth', 'From', 'Hello', 'People', 'Planet']

# %%
A=[22,23,24,26,27]
A.extend([21,28,29,30])
A.sort()
A
# Out:
# [21, 22, 23, 24, 26, 27, 28, 29, 30]

# %%
A.pop()
# Out:
# 30

# %%
A.reverse()
A
# Out:
# [29, 28, 27, 26, 24, 23, 22, 21]

# %%
A=[]
A.append(11)
A.append(12)
A.append(13)
A.append(14)
A.append(15)
A
# Out:
# [11, 12, 13, 14, 15]

# %%
A.pop()
A
# Out:
# [11, 12, 13]

# %%
A = ['Hello', 'Universe', 'Galaxy','Black']
del A[3]
A
# Out:
# ['Hello', 'Universe', 'Galaxy']

# %%
del A[1:-1]
A
# Out:
# ['Hello', 'Universe']

# %%
A=['Hello','World','Universe']
A[:1]=['Bye']
A
# Out:
# ['Bye', 'World', 'Universe']

# %%
A[0]=['Hello']
A
# Out:
# [['Hello'], 'World', 'Universe']

# %%
Car={'Name':'Porsche','Type':'Sports Car','Horsepower':783,'CC':6482}
Car['Type']
# Out:
# 'Sports Car'

# %%
len(Car)
# Out:
# 4

# %%
'Horsepower' in Car
# Out:
# True

# %%
Car.keys()
# Out:
# dict_keys(['Name', 'Type', 'Horsepower', 'CC'])

# %%
Car['Type']=['Hyper Car','Sedan','Hatchback']
Car
# Out:
# {'Name': 'Porsche',
#  'Type': ['Hyper Car', 'Sedan', 'Hatchback'],
#  'Horsepower': 783,
#  'CC': 6482}

# %%
del Car['CC']
Car['Version']='Carrera GT'
Car
# Out:
# {'Name': 'Porsche',
#  'Type': ['Hyper Car', 'Sedan', 'Hatchback'],
#  'Horsepower': 783,
#  'Version': 'Carrera GT'}

# %%
Car.get('Name')
# Out:
# 'Porsche'

# %%
Car.get('Speed')

# %%
Car.get('Speed',345)
# Out:
# {'Name': 'Porsche',
#  'Type': ['Hyper Car', 'Sedan', 'Hatchback'],
#  'Horsepower': 783,
#  'Version': 'Carrera GT'}
