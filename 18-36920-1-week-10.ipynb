# %% [markdown]
# #  Ahnaf Sayed, ID: 18-36920-1, Section-F, Week 10

# %% [markdown]
# # N Queen Attack Detection

# %%
import random
N = 4
r = []
c = []
for i in range(1, N+1):
    r.append(random.choice(range(1, N+1)))
    c.append(random.choice(range(1, N+1)))
    #check repetition of position
    print('Q{}: {},{}'.format(i,r[-1],c[-1]))
print(r)
print(c)
# Out:
# Q1: 1,1
# Q2: 4,1
# Q3: 3,1
# Q4: 2,2
# [1, 4, 3, 2]
# [1, 1, 1, 2]

# %%
# row attack
for i in range(0,N):
    for j in range(i+1,N):
        if(r[i] == r[j]):
            print('Row attack:row:{} column:{} and {}'.format(r[i],c[i],c[j]))
# Out:
# row attack: row:2 column:3 and 3

# %%
#column attack
for i in range(0,N):
    for j in range(i+1,N):
        if(c[i] == c[j]):
            print('Column attack:{} row:{} and {}' .format(c[i],r[i],r[j]))
# Out:
# column attack: 1 row:1 and 4
# column attack: 1 row:1 and 3
# column attack: 1 row:4 and 3

# %%
# diagonal atack
# by implementing abs(j - l) = abs(k - i)
for i in range(0,N):
      p=c[i]-c[i+1]
        if(p < 0):
            p=p*(-1) 
            
            
    for j in range(i+1,N):
        q=r[j]-r[j-1]
          if(q < 0):
            q=q*(-1)
                if(p == q):
                print('Diagonal attack:{} row :{} column:{}'.format(r[i],c[j]))
# Out:
#   File "<tokenize>", line 9
#     for j in range(i+1,N):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# implement a method to print a state is valid or not
# input r and c (two lists)

def is_valid(r[],c[],N)
 for i in range(0,N):
    for j in range(i+1,N):
        if(r[i] == r[j]):
            print('Row attack: row:{} column:{} and {}'.format(r[i],c[i],c[j]))
            
for i in range(0,N):
    for j in range(i+1,N):
        if(c[i] == c[j]):
            print('Column attack: column :{} row:{} and {}'.format(c[i],r[i],r[j]))
            
for i in range(0,N):
      p=c[i]-c[i+1]
        if(p < 0):
            p=p*(-1) 
for j in range(i+1,N):
        q=r[j]-r[j-1]
        if(q < 0):
            q=q*(-1)
        if(p == q):
            print('Diagonal attack: row :{} column:{}'.format(r[i],c[j]))
# Out:
#   File "<ipython-input-19-a122d0cf78b9>", line 4
#     def is_valid(r[],c[],N)
#                   ^
# SyntaxError: invalid syntax
