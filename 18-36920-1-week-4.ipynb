# %% [markdown]
# #  Ahnaf Sayed, ID: 18-36920-1, Section-F, Week 4

# %% [markdown]
# # BFS

# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %%
romanian_map['Zerind']['Oradea']
# Out:
# 71

# %%
romanian_map['Arad']['Zerind']
# Out:
# 75

# %%
romanian_map['Bucharest'].keys()
# Out:
# dict_keys(['Fagaras', 'Pitesti', 'Giurgiu', 'Urziceni'])

# %%
from queue import Queue


def bfs(startingNode, destinationNode):
    visited = {}  #to store explored nodes
    distance = {} #to store distance between two nodes
    parent = {}  #to store path

# %%
from queue import Queue


def bfs(startingNode, destinationNode):
    visited = {}  #to store explored nodes
    distance = {} #to store distance between two nodes
    parent = {}  #to store path

    bfs_traversal_output = []  #to store the order of traversal
    frontier = Queue()

    for city in romanian_map.keys():
        visited[city] = False
        parent[city] = None
        distance[city] = -1

    startingCity = startingNode
    visited[startingCity] = True
    distance[startingCity] = 0    #distance of starting city or node is 0
    frontier.put(startingCity)    #name of starting city of node =Arad
    found = False

    while not frontier.empty():
        u = frontier.get()     #in the first iteration it will be arad
        bfs_traversal_output.append(u)

        for v in romanian_map[u].keys(): #visited node is defined as u
            if not visited[v]:           #not visited node is defined as v     
                visited[v] = True
                parent[v] = u
                distance[v] = distance[u] + romanian_map[u][v]  #adding distance of visited node and distance between not visited node              
                frontier.put(v)  #storing the new child node in the frontier
                if v== destinationNode:  #check v as a destination node
                    found =True
                    break  #break of the for loop
                
        if found: break   
                               #continuation of while loop
    g = destinationNode   #parent node is defined as g
    path = []
    while g is not None:
        path.append(g)
        g = parent[g]
    
    path.reverse()
    print(path)
    print(distance[destinationNode])
    print(bfs_traversal_output)

bfs('Arad', 'Bucharest')
# Out:
# ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']
# 450
# ['Arad', 'Sibiu', 'Zerind', 'Timisoara', 'Oradea', 'Fagaras']

# %% [markdown]
# # Uniform Cost Search

# %%
from queue import PriorityQueue

def ucs(startingNode, destinationNode):
    visited = {}
    distance = {}
    parent = {}

    ucs_traversal_output = []
    frontier = PriorityQueue()

    for city in romanian_map.keys():
        visited[city] = False
        parent[city] = None
        distance[city] = -1

    startingCity = startingNode
    visited[startingCity] = True
    distance[startingCity] = 0
    frontier.put((0,startingCity))

    while not frontier.empty():
        u = frontier.get()[1]     
        ucs_traversal_output.append(u)
        if u== destinationNode:
            break
        visited[u] = True
        for v in romanian_map[u].keys():
            if not visited[v]:                
                parent[v] = u
                distance[v] = distance[u] + romanian_map[u][v]
                frontier.put((distance[v],v))

    g = destinationNode
    path = []
    while g is not None:
        path.append(g)
        g = parent[g]

    path.reverse()
    print(path)
    print(distance[destinationNode])
    print(ucs_traversal_output)


ucs('Arad', 'Bucharest')
# Out:
# ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']
# 418
# ['Arad', 'Zerind', 'Timisoara', 'Sibiu', 'Oradea', 'Rimnicu', 'Lugoj', 'Fagaras', 'Oradea', 'Mehadia', 'Pitesti', 'Craiova', 'Drobeta', 'Bucharest']

# %% [markdown]
# # DFS

# %%
frontier= []
frontier.append('Arad')
frontier.append('Zerind')
frontier.append('Oradea')
frontier
# Out:
# ['Arad', 'Zerind', 'Oradea']

# %%
frontier.pop(-1)
frontier
# Out:
# ['Arad', 'Zerind']
