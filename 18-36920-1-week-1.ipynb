# %% [markdown]
# #  Ahnaf Sayed, ID: 18-36920-1, Section-F, Week 1

# %% [markdown]
# # Number expression:

# %%
a=100
b=150
c=100
a+b+c
# Out:
# 350

# %%
(a+b+c)*4
# Out:
# 1400

# %%
(a+b+c)**6
# Out:
# 1838265625000000

# %%
print(a+b+c)
# Out:
# 350

# %%
a==c
# Out:
# True

# %%
a==b
# Out:
# False

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
import random
random.random()
# Out:
# 0.9189547897618761

# %%
random.choice([6,7,8,9])
# Out:
# 9

# %% [markdown]
# # String examples:

# %%
s= 'Bay of Bengal'
s
# Out:
# 'Bay of Bengal'

# %%
s[7]
# Out:
# 'B'

# %%
s[:]
# Out:
# 'Bay of Bengal'

# %%
s[7:]
# Out:
# 'Bengal'

# %%
s[-1]
# Out:
# 'l'

# %%
len(s)
# Out:
# 13

# %%
s[:3]
# Out:
# 'Bay'

# %%
s[:6]
# Out:
# 'Bay of'

# %%
s[:-2]
# Out:
# 'Bay of Beng'

# %%
s+' is situated at the south of Bangladesh'
# Out:
# 'Bay of Bengal is situated at the south of Bangladesh'

# %%
s*9
# Out:
# 'Bay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of BengalBay of Bengal'

# %%
s.find('Bengal')
# Out:
# 7

# %%
s.replace('Bengal','Bangladesh')
# Out:
# 'Bay of Bangladesh'

# %%
s='Bangladesh'+s[6:]
s
# Out:
# 'Bangladesh Bengal'

# %%
s.upper()
# Out:
# 'BANGLADESH BENGAL'

# %%
address='Uttara Dhaka 1230'
address.split(' ')
# Out:
# ['Uttara', 'Dhaka', '1230']

# %%
s.isalpha()
# Out:
# False

# %%
address=address.rstrip()
address
# Out:
# 'Uttara Dhaka 1230'

# %%
name='Bay of Bengal'
firstN=name.split(' ')[0]
lastN=name.split(' ')[-1]
print(firstN)
print(lastN)
# Out:
# Bay
# Bengal

# %% [markdown]
# # List examples:

# %%
D=[123,'Hello',3.1416,'World']
len(Digit)
# Out:
# 4

# %%
D+[7,8,9,10]
# Out:
# [123, 'Hello', 3.1416, 'World', 7, 8, 9, 10]

# %%
D[:-1]
# Out:
# [123, 'Hello', 3.1416]

# %%
D.append('Universe')
D
# Out:
# [123, 'Hello', 3.1416, 'World', 'Universe']

# %%
D.pop(4)
# Out:
# 'Universe'

# %% [markdown]
# Continue

# %%
D
# Out:
# [123, 'Hello', 3.1416, 'World']

# %%
A=['E','F','G','A','C','B','D']
A.sort()
A
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
A.reverse()
A
# Out:
# ['G', 'F', 'E', 'D', 'C', 'B', 'A']

# %%
A=[[7,8,9],
  [2,3,4],
  [6,5,2]]
A
# Out:
# [[7, 8, 9], [2, 3, 4], [6, 5, 2]]

# %%
A[2]
# Out:
# [6, 5, 2]

# %%
A[0][1]
